# %% [markdown]
# import numpy as np
#
# # Student Marks Dataset (out of 100)
# marks = np.array([45, 67, 89, 90, 56, 78, 88, 92, 61, 74,
#                   83, 95, 52, 68, 71, 85, 77, 64, 58, 81])
#
# print("Dataset:")
# print(marks)
#
# ## Statistics Practice Questions
#
# | No. | Question |
# |---:|---|
# | 1 | Find the mean of the dataset. |
# | 2 | Find the median of the dataset. |
# | 3 | Find the mode of the dataset (if any). |
# | 4 | Find the maximum and minimum values. |
# | 5 | Calculate the range of the dataset. |
# | 6 | Find the variance of the dataset. |
# | 7 | Find the standard deviation of the dataset. |
# | 8 | Calculate the 25th percentile (Q1). |
# | 9 | Calculate the 50th percentile (Q2/Median). |
# | 10 | Calculate the 75th percentile (Q3). |
# | 11 | Find the Interquartile Range (IQR). |
# | 12 | Count how many students scored above the mean. |
# | 13 | Count how many students scored below 60. |
# | 14 | Find the sum of all marks and calculate the average manually using NumPy. |
# | 15 | Sort the array in ascending and descending order, then find the top 5 highest scores. |

# %%
import numpy as np

# Student Marks Dataset (out of 100)
marks = np.array([45, 67, 89, 90, 56, 78, 88, 92, 61, 74,
                  83, 95, 52, 68, 71, 85, 77, 64, 58, 81])

print("Dataset:")
print(marks)
# Out:
# Dataset:
# [45 67 89 90 56 78 88 92 61 74 83 95 52 68 71 85 77 64 58 81]
