# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.DataFrame({
    "Order_ID": [101,102,103,104,105,106,107,108,109,110,
                 111,112,113,114,115,116,117,118,119,120],
    "Order_DateTime": [
        "2025-01-05 09:15:30","2025-01-12 14:45:20","2025-02-03 11:20:10",
        "2025-02-18 16:35:45","2025-03-07 10:05:25","2025-03-25 18:50:40",
        "2025-04-10 08:30:15","2025-04-22 13:40:55","2025-05-05 17:10:35",
        "2025-05-28 12:25:50","2025-06-11 15:45:05","2025-06-30 19:20:30",
        "2025-07-04 09:55:15","2025-07-19 11:15:40","2025-08-08 14:05:25",
        "2025-08-26 16:50:10","2025-09-09 10:40:20","2025-10-14 18:30:45",
        "2025-11-21 13:15:35","2025-12-30 20:10:50"
    ],
    "Customer": [
        "Rohit","Virat","Dhoni","Rahul","Hardik","Gill","Ishan","Pant","Surya","Bumrah",
        "KL Rahul","Jadeja","Ashwin","Shami","Siraj","Axar","Kuldeep","Arshdeep","Rinku","Tilak"
    ],
    "City": [
        "Delhi","Mumbai","Chennai","Lucknow","Pune","Ahmedabad","Kolkata","Jaipur","Hyderabad","Delhi",
        "Mumbai","Chennai","Lucknow","Pune","Ahmedabad","Kolkata","Hyderabad","Jaipur","Delhi","Mumbai"
    ],
    "Product": [
        "Laptop","Mobile","Tablet","Headphones","Keyboard","Mouse","Monitor","Printer","Camera","Laptop",
        "Mobile","Tablet","Keyboard","Mouse","Monitor","Printer","Camera","Laptop","Tablet","Mobile"
    ],
    "Sales": [
        65000,25000,18000,2500,1800,900,15000,12000,45000,70000,
        28000,20000,2200,1000,17000,14000,48000,72000,21000,30000
    ]
})

# sales_df["Order_DateTime"] = pd.to_datetime(sales_df["Order_DateTime"])
# sales_df = sales_df.sort_values("Order_DateTime").set_index("Order_DateTime")

# ax_sales = sales_df["Sales"].plot(kind="line", marker="o", figsize=(10,6), title="Sales over Time")
# ax_sales.set_xlabel("Order DateTime")
# ax_sales.set_ylabel("Sales")
# plt.xticks(rotation=45)
# plt.tight_layout()
# plt.show()

df.plot(x='Product', y='Sales', kind='barh',figsize=(18,5), color = 'blue')
df.plot(x='Product', y='Sales', kind='pie',figsize=(18,5), color = 'blue')
df.plot(x='Product', y='Sales', kind='scatter',figsize=(18,5), color = 'blue', marker='o')
df.plot(x='Product', y='Sales', kind='line',figsize=(18,5), color = 'blue', marker='o')
# Out:
# <Axes: xlabel='Product'>

# %%
df = {"City": ["Delhi", "Mumbai", "Chennai", "Lucknow", "Pune", "Ahmedabad", "Kolkata", "Jaipur", "Hyderabad"],
      "Population": [135000, 832000, 338000, 413200, 350000, 250000, 450000, 300000, 380000]}

df = pd.DataFrame(df)   
df.plot(x='City', y='Population', kind='pie',figsize=(18,5), color='red')
df.plot(x='City', y='Population', kind='barh',figsize=(18,5), color='blue')
df.plot(x='City', y='Population', kind='scatter',figsize=(18,5), color='green')
df.plot(x='City', y='Population', kind='bar',figsize=(18,5), color='black')
df.plot(x='City', y='Population', kind='line',figsize=(18,5), color='purple')
# Out:
# <Axes: xlabel='City'>

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame({
    "Month": ["FEB", "MAR", "APR", "MAY", "JUN", "JUL", "AUG", "SEP", "OCT", "NOV"],
    "Sales": [20000, 30000, 40000, 50000, 60000, 70000, 80000, 90000, 100000, 110000]
})

plt.figure(figsize=(8, 5), facecolor="lightgray")
plt.plot(df["Month"], df["Sales"], marker="o")
plt.title("Monthly Sales")
plt.xlabel("Month")
plt.ylabel("Sales")
plt.grid()
plt.gca().set_facecolor("lightyellow")
plt.show()
