# %% [markdown]
# # Author : Harshit Tiwari
# ## Roll number : 1230432322

# %%
import pandas as pd
from io import StringIO

data = """,ID,Name,Age,City,Marks,Department,Salary
0,1,Aarav,19,Lucknow,85,CS,30000
1,2,Vivaan,20,Delhi,90,IT,32000
2,3,Aditya,21,Mumbai,78,CS,28000
3,4,Vihaan,22,Pune,88,IT,35000
4,5,Arjun,20,Kanpur,92,EC,40000
5,6,Reyansh,23,Noida,76,CS,27000
6,7,Shaurya,21,Agra,81,IT,33000
7,8,Krishna,22,Jaipur,95,EC,42000
8,9,Ishaan,19,Delhi,89,CS,31000
9,10,Kabir,20,Mumbai,84,IT,34000
10,11,Rohan,21,Pune,73,EC,29000
11,12,Kunal,22,Lucknow,77,CS,30000
12,13,Samar,23,Kanpur,80,IT,36000
13,14,Yash,20,Noida,91,EC,41000
14,15,Dev,19,Agra,87,CS,30500
15,16,Ayaan,21,Jaipur,79,IT,32500
16,17,Rudra,22,Delhi,83,EC,38000
17,18,Om,20,Mumbai,86,CS,31500
18,19,Aryan,21,Pune,90,IT,34500
19,20,Parth,23,Lucknow,88,EC,39500
"""

df = pd.read_csv(StringIO(data))
print(df)
# Out:
#     Unnamed: 0  ID     Name  Age     City  Marks Department  Salary
# 0            0   1    Aarav   19  Lucknow     85         CS   30000
# 1            1   2   Vivaan   20    Delhi     90         IT   32000
# 2            2   3   Aditya   21   Mumbai     78         CS   28000
# 3            3   4   Vihaan   22     Pune     88         IT   35000
# 4            4   5    Arjun   20   Kanpur     92         EC   40000
# 5            5   6  Reyansh   23    Noida     76         CS   27000
# 6            6   7  Shaurya   21     Agra     81         IT   33000
# 7            7   8  Krishna   22   Jaipur     95         EC   42000
# 8            8   9   Ishaan   19    Delhi     89         CS   31000
# 9            9  10    Kabir   20   Mumbai     84         IT   34000
# 10          10  11    Rohan   21     Pune     73         EC   29000
# 11          11  12    Kunal   22  Lucknow     77         CS   30000
# 12          12  13    Samar   23   Kanpur     80         IT   36000
# 13          13  14     Yash   20    Noida     91         EC   41000
# 14          14  15      Dev   19     Agra     87         CS   30500
# 15          15  16    Ayaan   21   Jaipur     79         IT   32500
# 16          16  17    Rudra   22    Delhi     83         EC   38000
# 17          17  18       Om   20   Mumbai     86         CS   31500
# 18          18  19    Aryan   21     Pune     90         IT   34500
# 19          19  20    Parth   23  Lucknow     88         EC   39500

# %%
print("1. Marks > 85:\n", df[df["Marks"] > 85])
print("2. Age == 20:\n", df[df["Age"] == 20])
print("3. City == Delhi:\n", df[df["City"] == "Delhi"])
print("4. City == Mumbai:\n", df[df["City"] == "Mumbai"])
print("5. Salary > 35000:\n", df[df["Salary"] > 35000])
print("6. Marks < 80:\n", df[df["Marks"] < 80])
print("7. Age > 21:\n", df[df["Age"] > 21])
print("8. Department == CS:\n", df[df["Department"] == "CS"])
print("9. Department == IT:\n", df[df["Department"] == "IT"])
print("10. City == Lucknow:\n", df[df["City"] == "Lucknow"])

print("11. Marks > 80 and Age < 21:\n", df[(df["Marks"] > 80) & (df["Age"] < 21)])
print("12. City == Delhi and Marks > 85:\n", df[(df["City"] == "Delhi") & (df["Marks"] > 85)])
print("13. City == Mumbai or Pune:\n", df[df["City"].isin(["Mumbai", "Pune"])])
print("14. Not from Lucknow:\n", df[df["City"] != "Lucknow"])
print("15. Marks between 80 and 90:\n", df[df["Marks"].between(80, 90)])
print("16. Department == CS or EC:\n", df[df["Department"].isin(["CS", "EC"])])
print("17. Salary > 32000 and Department == IT:\n", df[(df["Salary"] > 32000) & (df["Department"] == "IT")])
print("18. Age == 21 or Marks > 90:\n", df[(df["Age"] == 21) | (df["Marks"] > 90)])
print("19. City in Delhi, Mumbai, Lucknow:\n", df[df["City"].isin(["Delhi", "Mumbai", "Lucknow"])])
print("20. Marks > 85 and Age >= 20:\n", df[(df["Marks"] > 85) & (df["Age"] >= 20)])
# Out:
# 1. Marks > 85:
#      Unnamed: 0  ID     Name  Age     City  Marks Department  Salary
# 1            1   2   Vivaan   20    Delhi     90         IT   32000
# 3            3   4   Vihaan   22     Pune     88         IT   35000
# 4            4   5    Arjun   20   Kanpur     92         EC   40000
# 7            7   8  Krishna   22   Jaipur     95         EC   42000
# 8            8   9   Ishaan   19    Delhi     89         CS   31000
# 13          13  14     Yash   20    Noida     91         EC   41000
# 14          14  15      Dev   19     Agra     87         CS   30500
# 17          17  18       Om   20   Mumbai     86         CS   31500
# 18          18  19    Aryan   21     Pune     90         IT   34500
# 19          19  20    Parth   23  Lucknow     88         EC   39500
# 2. Age == 20:
#      Unnamed: 0  ID    Name  Age    City  Marks Department  Salary
# 1            1   2  Vivaan   20   Delhi     90         IT   32000
# 4            4   5   Arjun   20  Kanpur     92         EC   40000
# 9            9  10   Kabir   20  Mumbai     84         IT   34000
# 13          13  14    Yash   20   Noida     91         EC   41000
# 17          17  18      Om   20  Mumbai     86         CS   31500
# 3. City == Delhi:
#      Unnamed: 0  ID    Name  Age   City  Marks Department  Salary
# 1            1   2  Vivaan   20  Delhi     90         IT   32000
# 8            8   9  Ishaan   19  Delhi     89         CS   31000
# 16          16  17   Rudra   22  Delhi     83         EC   38000
# 4. City == Mumbai:
#      Unnamed: 0  ID    Name  Age    City  Marks Department  Salary
# 2            2   3  Aditya   21  Mumbai     78         CS   28000
# 9            9  10   Kabir   20  Mumbai     84         IT   34000
# 17          17  18      Om   20  Mumbai     86         CS   31500
# 5. Salary > 35000:
#      Unnamed: 0  ID     Name  Age     City  Marks Department  Salary
# 4            4   5    Arjun   20   Kanpur     92         EC   40000
# 7            7   8  Krishna   22   Jaipur     95         EC   42000
# 12          12  13    Samar   23   Kanpur     80         IT   36000
# 13          13  14     Yash   20    Noida     91         EC   41000
# 16          16  17    Rudra   22    Delhi     83         EC   38000
# 19          19  20    Parth   23  Lucknow     88         EC   39500
# 6. Marks < 80:
#      Unnamed: 0  ID     Name  Age     City  Marks Department  Salary
# 2            2   3   Aditya   21   Mumbai     78         CS   28000
# 5            5   6  Reyansh   23    Noida     76         CS   27000
# 10          10  11    Rohan   21     Pune     73         EC   29000
# 11          11  12    Kunal   22  Lucknow     77         CS   30000
# 15          15  16    Ayaan   21   Jaipur     79         IT   32500
# 7. Age > 21:
#      Unnamed: 0  ID     Name  Age     City  Marks Department  Salary
# 3            3   4   Vihaan   22     Pune     88         IT   35000
# 5            5   6  Reyansh   23    Noida     76         CS   27000
# 7            7   8  Krishna   22   Jaipur     95         EC   42000
# 11          11  12    Kunal   22  Lucknow     77         CS   30000
# 12          12  13    Samar   23   Kanpur     80         IT   36000
# 16          16  17    Rudra   22    Delhi     83         EC   38000
# 19          19  20    Parth   23  Lucknow     88         EC   39500
# 8. Department == CS:
#      Unnamed: 0  ID     Name  Age     City  Marks Department  Salary
# 0            0   1    Aarav   19  Lucknow     85         CS   30000
# 2            2   3   Aditya   21   Mumbai     78         CS   28000
# 5            5   6  Reyansh   23    Noida     76         CS   27000
# 8            8   9   Ishaan   19    Delhi     89         CS   31000
# 11          11  12    Kunal   22  Lucknow     77         CS   30000
# 14          14  15      Dev   19     Agra     87         CS   30500
# 17          17  18       Om   20   Mumbai     86         CS   31500
# 9. Department == IT:
#      Unnamed: 0  ID     Name  Age    City  Marks Department  Salary
# 1            1   2   Vivaan   20   Delhi     90         IT   32000
# 3            3   4   Vihaan   22    Pune     88         IT   35000
# 6            6   7  Shaurya   21    Agra     81         IT   33000
# 9            9  10    Kabir   20  Mumbai     84         IT   34000
# 12          12  13    Samar   23  Kanpur     80         IT   36000
# 15          15  16    Ayaan   21  Jaipur     79         IT   32500
# 18          18  19    Aryan   21    Pune     90         IT   34500
# 10. City == Lucknow:
#      Unnamed: 0  ID   Name  Age     City  Marks Department  Salary
# 0            0   1  Aarav   19  Lucknow     85         CS   30000
# 11          11  12  Kunal   22  Lucknow     77         CS   30000
# 19          19  20  Parth   23  Lucknow     88         EC   39500
# 11. Marks > 80 and Age < 21:
#      Unnamed: 0  ID    Name  Age     City  Marks Department  Salary
# 0            0   1   Aarav   19  Lucknow     85         CS   30000
# 1            1   2  Vivaan   20    Delhi     90         IT   32000
# 4            4   5   Arjun   20   Kanpur     92         EC   40000
# 8            8   9  Ishaan   19    Delhi     89         CS   31000
# 9            9  10   Kabir   20   Mumbai     84         IT   34000
# 13          13  14    Yash   20    Noida     91         EC   41000
# 14          14  15     Dev   19     Agra     87         CS   30500
# 17          17  18      Om   20   Mumbai     86         CS   31500
# 12. City == Delhi and Marks > 85:
#     Unnamed: 0  ID    Name  Age   City  Marks Department  Salary
# 1           1   2  Vivaan   20  Delhi     90         IT   32000
# 8           8   9  Ishaan   19  Delhi     89         CS   31000
# 13. City == Mumbai or Pune:
#      Unnamed: 0  ID    Name  Age    City  Marks Department  Salary
# 2            2   3  Aditya   21  Mumbai     78         CS   28000
# 3            3   4  Vihaan   22    Pune     88         IT   35000
# 9            9  10   Kabir   20  Mumbai     84         IT   34000
# 10          10  11   Rohan   21    Pune     73         EC   29000
# 17          17  18      Om   20  Mumbai     86         CS   31500
# 18          18  19   Aryan   21    Pune     90         IT   34500
# 14. Not from Lucknow:
#      Unnamed: 0  ID     Name  Age    City  Marks Department  Salary
# 1            1   2   Vivaan   20   Delhi     90         IT   32000
# 2            2   3   Aditya   21  Mumbai     78         CS   28000
# 3            3   4   Vihaan   22    Pune     88         IT   35000
# 4            4   5    Arjun   20  Kanpur     92         EC   40000
# 5            5   6  Reyansh   23   Noida     76         CS   27000
# 6            6   7  Shaurya   21    Agra     81         IT   33000
# 7            7   8  Krishna   22  Jaipur     95         EC   42000
# 8            8   9   Ishaan   19   Delhi     89         CS   31000
# 9            9  10    Kabir   20  Mumbai     84         IT   34000
# 10          10  11    Rohan   21    Pune     73         EC   29000
# 12          12  13    Samar   23  Kanpur     80         IT   36000
# 13          13  14     Yash   20   Noida     91         EC   41000
# 14          14  15      Dev   19    Agra     87         CS   30500
# 15          15  16    Ayaan   21  Jaipur     79         IT   32500
# 16          16  17    Rudra   22   Delhi     83         EC   38000
# 17          17  18       Om   20  Mumbai     86         CS   31500
# 18          18  19    Aryan   21    Pune     90         IT   34500
# 15. Marks between 80 and 90:
#      Unnamed: 0  ID     Name  Age     City  Marks Department  Salary
# 0            0   1    Aarav   19  Lucknow     85         CS   30000
# 1            1   2   Vivaan   20    Delhi     90         IT   32000
# 3            3   4   Vihaan   22     Pune     88         IT   35000
# 6            6   7  Shaurya   21     Agra     81         IT   33000
# 8            8   9   Ishaan   19    Delhi     89         CS   31000
# 9            9  10    Kabir   20   Mumbai     84         IT   34000
# 12          12  13    Samar   23   Kanpur     80         IT   36000
# 14          14  15      Dev   19     Agra     87         CS   30500
# 16          16  17    Rudra   22    Delhi     83         EC   38000
# 17          17  18       Om   20   Mumbai     86         CS   31500
# 18          18  19    Aryan   21     Pune     90         IT   34500
# 19          19  20    Parth   23  Lucknow     88         EC   39500
# 16. Department == CS or EC:
#      Unnamed: 0  ID     Name  Age     City  Marks Department  Salary
# 0            0   1    Aarav   19  Lucknow     85         CS   30000
# 2            2   3   Aditya   21   Mumbai     78         CS   28000
# 4            4   5    Arjun   20   Kanpur     92         EC   40000
# 5            5   6  Reyansh   23    Noida     76         CS   27000
# 7            7   8  Krishna   22   Jaipur     95         EC   42000
# 8            8   9   Ishaan   19    Delhi     89         CS   31000
# 10          10  11    Rohan   21     Pune     73         EC   29000
# 11          11  12    Kunal   22  Lucknow     77         CS   30000
# 13          13  14     Yash   20    Noida     91         EC   41000
# 14          14  15      Dev   19     Agra     87         CS   30500
# 16          16  17    Rudra   22    Delhi     83         EC   38000
# 17          17  18       Om   20   Mumbai     86         CS   31500
# 19          19  20    Parth   23  Lucknow     88         EC   39500
# 17. Salary > 32000 and Department == IT:
#      Unnamed: 0  ID     Name  Age    City  Marks Department  Salary
# 3            3   4   Vihaan   22    Pune     88         IT   35000
# 6            6   7  Shaurya   21    Agra     81         IT   33000
# 9            9  10    Kabir   20  Mumbai     84         IT   34000
# 12          12  13    Samar   23  Kanpur     80         IT   36000
# 15          15  16    Ayaan   21  Jaipur     79         IT   32500
# 18          18  19    Aryan   21    Pune     90         IT   34500
# 18. Age == 21 or Marks > 90:
#      Unnamed: 0  ID     Name  Age    City  Marks Department  Salary
# 2            2   3   Aditya   21  Mumbai     78         CS   28000
# 4            4   5    Arjun   20  Kanpur     92         EC   40000
# 6            6   7  Shaurya   21    Agra     81         IT   33000
# 7            7   8  Krishna   22  Jaipur     95         EC   42000
# 10          10  11    Rohan   21    Pune     73         EC   29000
# 13          13  14     Yash   20   Noida     91         EC   41000
# 15          15  16    Ayaan   21  Jaipur     79         IT   32500
# 18          18  19    Aryan   21    Pune     90         IT   34500
# 19. City in Delhi, Mumbai, Lucknow:
#      Unnamed: 0  ID    Name  Age     City  Marks Department  Salary
# 0            0   1   Aarav   19  Lucknow     85         CS   30000
# 1            1   2  Vivaan   20    Delhi     90         IT   32000
# 2            2   3  Aditya   21   Mumbai     78         CS   28000
# 8            8   9  Ishaan   19    Delhi     89         CS   31000
# 9            9  10   Kabir   20   Mumbai     84         IT   34000
# 11          11  12   Kunal   22  Lucknow     77         CS   30000
# 16          16  17   Rudra   22    Delhi     83         EC   38000
# 17          17  18      Om   20   Mumbai     86         CS   31500
# 19          19  20   Parth   23  Lucknow     88         EC   39500
# 20. Marks > 85 and Age >= 20:
#      Unnamed: 0  ID     Name  Age     City  Marks Department  Salary
# 1            1   2   Vivaan   20    Delhi     90         IT   32000
# 3            3   4   Vihaan   22     Pune     88         IT   35000
# 4            4   5    Arjun   20   Kanpur     92         EC   40000
# 7            7   8  Krishna   22   Jaipur     95         EC   42000
# 13          13  14     Yash   20    Noida     91         EC   41000
# 17          17  18       Om   20   Mumbai     86         CS   31500
# 18          18  19    Aryan   21     Pune     90         IT   34500
# 19          19  20    Parth   23  Lucknow     88         EC   39500
