# %%
import pandas as pd
import numpy as np

# %%
# Adding csv data to pandas dataframe pd
df = pd.read_csv("/Users/iamharshit188/Desktop/tech/DSAI/MachineLearning/Streamlit_LinearRegression/Employee.csv.xls")

# %%
df.head()
# Out:
#         Name  Education  ...  ExperienceInCurrentDomain LeaveOrNot
# 0  Sanskriti  Bachelors  ...                          0          0
# 1     Kartik  Bachelors  ...                          3          1
# 2      Bindu  Bachelors  ...                          2          0
# 3     Sudevi    Masters  ...                          5          1
# 4       Joni    Masters  ...                          2          1
#
# [5 rows x 11 columns]

# %%
df.tail()
# Out:
#           Name  Education  ...  ExperienceInCurrentDomain LeaveOrNot
# 4648  Vishakha  Bachelors  ...                          4          0
# 4649     Gross    Masters  ...                          2          1
# 4650    Sewall    Masters  ...                          5          1
# 4651    Conant  Bachelors  ...                          2          0
# 4652    Clytie  Bachelors  ...                          4          0
#
# [5 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4653 entries, 0 to 4652
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Name                       4653 non-null   object
#  1   Education                  4650 non-null   object
#  2   JoiningYear                4653 non-null   int64
#  3   City                       4651 non-null   object
#  4   Salary                     4649 non-null   float64
#  5   PaymentTier                4653 non-null   int64
#  6   Age                        4653 non-null   int64
#  7   Gender                     4653 non-null   object
#  8   EverBenched                4653 non-null   object
#  9   ExperienceInCurrentDomain  4653 non-null   int64
#  10  LeaveOrNot                 4653 non-null   int64
# dtypes: float64(1), int64(5), object(5)
# memory usage: 400.0+ KB

# %%
#creating a graph of the data to visualize the data
import matplotlib.pyplot as plt

df.plot(x='City', y='Salary', style='o' , kind='bar')
plt.xlabel('City')
plt.ylabel('Salary')
plt.title('Salary vs City')
plt.show()
