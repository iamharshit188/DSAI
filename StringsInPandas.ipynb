# %%
import pandas as pd

sales_df = pd.DataFrame({
    "Order_ID": [101,102,103,104,105,106,107,108,109,110,
                 111,112,113,114,115,116,117,118,119,120],

    "Order_DateTime": [
        "2025-01-05 09:15:30",
        "2025-01-12 14:45:20",
        "2025-02-03 11:20:10",
        "2025-02-18 16:35:45",
        "2025-03-07 10:05:25",
        "2025-03-25 18:50:40",
        "2025-04-10 08:30:15",
        "2025-04-22 13:40:55",
        "2025-05-05 17:10:35",
        "2025-05-28 12:25:50",
        "2025-06-11 15:45:05",
        "2025-06-30 19:20:30",
        "2025-07-04 09:55:15",
        "2025-07-19 11:15:40",
        "2025-08-08 14:05:25",
        "2025-08-26 16:50:10",
        "2025-09-09 10:40:20",
        "2025-10-14 18:30:45",
        "2025-11-21 13:15:35",
        "2025-12-30 20:10:50"
    ],

    "Customer": [
        "Rohit","Virat","Dhoni","Rahul","Hardik",
        "Gill","Ishan","Pant","Surya","Bumrah",
        "KL Rahul","Jadeja","Ashwin","Shami","Siraj",
        "Axar","Kuldeep","Arshdeep","Rinku","Tilak"
    ],

    "City": [
        "Delhi","Mumbai","Chennai","Lucknow","Pune",
        "Ahmedabad","Kolkata","Jaipur","Hyderabad","Delhi",
        "Mumbai","Chennai","Lucknow","Pune","Ahmedabad",
        "Kolkata","Hyderabad","Jaipur","Delhi","Mumbai"
    ],

    "Product": [
        "Laptop","Mobile","Tablet","Headphones","Keyboard",
        "Mouse","Monitor","Printer","Camera","Laptop",
        "Mobile","Tablet","Keyboard","Mouse","Monitor",
        "Printer","Camera","Laptop","Tablet","Mobile"
    ],

    "Sales": [
        65000,25000,18000,2500,1800,
        900,15000,12000,45000,70000,
        28000,20000,2200,1000,17000,
        14000,48000,72000,21000,30000
    ]
})

# Convert to DateTime
sales_df["Order_DateTime"] = pd.to_datetime(sales_df["Order_DateTime"])

print(sales_df)
# Out:
#     Order_ID      Order_DateTime  Customer       City     Product  Sales
# 0        101 2025-01-05 09:15:30     Rohit      Delhi      Laptop  65000
# 1        102 2025-01-12 14:45:20     Virat     Mumbai      Mobile  25000
# 2        103 2025-02-03 11:20:10     Dhoni    Chennai      Tablet  18000
# 3        104 2025-02-18 16:35:45     Rahul    Lucknow  Headphones   2500
# 4        105 2025-03-07 10:05:25    Hardik       Pune    Keyboard   1800
# 5        106 2025-03-25 18:50:40      Gill  Ahmedabad       Mouse    900
# 6        107 2025-04-10 08:30:15     Ishan    Kolkata     Monitor  15000
# 7        108 2025-04-22 13:40:55      Pant     Jaipur     Printer  12000
# 8        109 2025-05-05 17:10:35     Surya  Hyderabad      Camera  45000
# 9        110 2025-05-28 12:25:50    Bumrah      Delhi      Laptop  70000
# 10       111 2025-06-11 15:45:05  KL Rahul     Mumbai      Mobile  28000
# 11       112 2025-06-30 19:20:30    Jadeja    Chennai      Tablet  20000
# 12       113 2025-07-04 09:55:15    Ashwin    Lucknow    Keyboard   2200
# 13       114 2025-07-19 11:15:40     Shami       Pune       Mouse   1000
# 14       115 2025-08-08 14:05:25     Siraj  Ahmedabad     Monitor  17000
# 15       116 2025-08-26 16:50:10      Axar    Kolkata     Printer  14000
# 16       117 2025-09-09 10:40:20   Kuldeep  Hyderabad      Camera  48000
# 17       118 2025-10-14 18:30:45  Arshdeep     Jaipur      Laptop  72000
# 18       119 2025-11-21 13:15:35     Rinku      Delhi      Tablet  21000
# 19       120 2025-12-30 20:10:50     Tilak     Mumbai      Mobile  30000

# %%
str_ops_df = pd.DataFrame({
    "Customer": s,
    "lower": s.str.lower(),
    "upper": s.str.upper(),
    "title": s.str.title(),
    "strip": s.str.strip(),
    "len": s.str.len(),
    "first_name": s.str.split(" ", n=1).str.get(0),
    "last_name": s.str.split(" ", n=1).str.get(1),
    "startswith_R": s.str.startswith("R"),
 

})

str_ops_df
# Out:
#     Customer     lower     upper     title     strip  len first_name  \
# 0      Rohit     rohit     ROHIT     Rohit     Rohit    5      Rohit
# 1      Virat     virat     VIRAT     Virat     Virat    5      Virat
# 2      Dhoni     dhoni     DHONI     Dhoni     Dhoni    5      Dhoni
# 3      Rahul     rahul     RAHUL     Rahul     Rahul    5      Rahul
# 4     Hardik    hardik    HARDIK    Hardik    Hardik    6     Hardik
# 5       Gill      gill      GILL      Gill      Gill    4       Gill
# 6      Ishan     ishan     ISHAN     Ishan     Ishan    5      Ishan
# 7       Pant      pant      PANT      Pant      Pant    4       Pant
# 8      Surya     surya     SURYA     Surya     Surya    5      Surya
# 9     Bumrah    bumrah    BUMRAH    Bumrah    Bumrah    6     Bumrah
# 10  KL Rahul  kl rahul  KL RAHUL  Kl Rahul  KL Rahul    8         KL
# 11    Jadeja    jadeja    JADEJA    Jadeja    Jadeja    6     Jadeja
# 12    Ashwin    ashwin    ASHWIN    Ashwin    Ashwin    6     Ashwin
# 13     Shami     shami     SHAMI     Shami     Shami    5      Shami
# 14     Siraj     siraj     SIRAJ     Siraj     Siraj    5      Siraj
# 15      Axar      axar      AXAR      Axar      Axar    4       Axar
# 16   Kuldeep   kuldeep   KULDEEP   Kuldeep   Kuldeep    7    Kuldeep
# 17  Arshdeep  arshdeep  ARSHDEEP  Arshdeep  Arshdeep    8   Arshdeep
# 18     Rinku     rinku     RINKU     Rinku     Rinku    5      Rinku
# 19     Tilak     tilak     TILAK     Tilak     Tilak    5      Tilak
#
#    last_name  startswith_R
# 0        NaN          True
# 1        NaN         False
# 2        NaN         False
# 3        NaN          True
# 4        NaN         False
# 5        NaN         False
# 6        NaN         False
# 7        NaN         False
# 8        NaN         False
# 9        NaN         False
# 10     Rahul         False
# 11       NaN         False
# 12       NaN         False
# 13       NaN         False
# 14       NaN         False
# 15       NaN         False
# 16       NaN         False
# 17       NaN         False
# 18       NaN          True
# 19       NaN         False
