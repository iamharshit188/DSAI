# %%
# !uv pip install tensorflow
# Out:
# Using Python 3.9.6 environment at: /Users/iamharshit188/Desktop/tech/DSAI/.venv
# Resolved 40 packages in 18.20s
# ⠼ Preparing packages... (0/23)
# ⠼ Preparing packages... (0/23)------------------     0 B/31.46 KiB
# ⠼ Preparing packages... (0/23)------------------     0 B/31.46 KiB
# flatbuffers          ------------------------------     0 B/26.04 KiB
# ⠼ Preparing packages... (0/23)------------------     0 B/31.46 KiB
# flatbuffers          ------------------------------     0 B/26.04 KiB
# ⠼ Preparing packages... (0/23)------------------     0 B/31.46 KiB
# flatbuffers          ------------------------------     0 B/26.04 KiB
# ⠼ Preparing packages... (0/23)------------------     0 B/31.46 KiB
# flatbuffers          ------------------------------     0 B/26.04 KiB
# wheel                ------------------------------     0 B/31.46 KiB
# ⠼ Preparing packages... (0/23)------------------     0 B/132.63 KiB
# flatbuffers          ------------------------------ 14.79 KiB/26.04 KiB
# wheel                ------------------------------     0 B/31.46 KiB
# ⠼ Preparing packages... (0/23)------------------     0 B/132.63 KiB
# flatbuffers          ------------------------------ 14.79 KiB/26.04 KiB
# wheel                ------------------------------     0 B/31.46 KiB
# ⠼ Preparing packages... (0/23)------------------     0 B/132.63 KiB
# flatbuffers          ------------------------------ 14.79 KiB/26.04 KiB
# wheel                ------------------------------     0 B/31.46 KiB
# ⠼ Preparing packages... (0/23)------------------     0 B/132.63 KiB
# flatbuffers          ------------------------------ 14.79 KiB/26.04 KiB
# wheel                ------------------------------     0 B/31.46 KiB
# ⠼ Preparing packages... (0/23)------------------     0 B/132.63 KiB
# astunparse           ------------------------------     0 B/12.43 KiB
# flatbuffers          ------------------------------ 14.79 KiB/26.04 KiB
# wheel                ------------------------------     0 B/31.46 KiB
# ⠼ Preparing packages... (0/23)------------------     0 B/132.63 KiB
# astunparse           ------------------------------     0 B/12.43 KiB
# flatbuffers          ------------------------------ 26.04 KiB/26.04 KiB
# wheel                ------------------------------     0 B/31.46 KiB
# ⠴ Preparing packages... (0/23)------------------     0 B/132.63 KiB
# astunparse           ------------------------------     0 B/12.43 KiB
# flatbuffers          ------------------------------ 26.04 KiB/26.04 KiB
# wheel                ------------------------------     0 B/31.46 KiB
# ⠴ Preparing packages... (0/23)------------------     0 B/132.63 KiB
# astunparse           ------------------------------     0 B/12.43 KiB
# flatbuffers          ------------------------------ 26.04 KiB/26.04 KiB
# wheel                ------------------------------     0 B/31.46 KiB
# ⠴ Preparing packages... (0/23)------------------     0 B/132.63 KiB
# astunparse           ------------------------------     0 B/12.43 KiB
# wheel                ------------------------------     0 B/31.46 KiB
# ⠴ Preparing packages... (0/23)------------------     0 B/132.63 KiB
# astunparse           ------------------------------ 12.43 KiB/12.43 KiB
# wheel                ------------------------------     0 B/31.46 KiB
# ⠴ Preparing packages... (0/23)------------------     0 B/132.63 KiB
# astunparse           ------------------------------ 12.43 KiB/12.43 KiB
# wheel                ------------------------------     0 B/31.46 KiB
# ⠴ Preparing packages... (0/23)------------------     0 B/132.63 KiB
# wheel                ------------------------------     0 B/31.46 KiB
# ⠴ Preparing packages... (0/23)------------------     0 B/132.63 KiB
# wheel                ------------------------------ 16.00 KiB/31.46 KiB
# ⠴ Preparing packages... (0/23)------------------     0 B/132.63 KiB
# wheel                ------------------------------ 27.18 KiB/31.46 KiB
# ⠴ Preparing packages... (0/23)------------------     0 B/132.63 KiB
# wheel                ------------------------------ 27.18 KiB/31.46 KiB
# ⠴ Preparing packages... (0/23)------------------     0 B/132.63 KiB
# wheel                ------------------------------ 27.18 KiB/31.46 KiB
# ⠴ Preparing packages... (0/23)------------------     0 B/132.63 KiB
# gast                 ------------------------------     0 B/22.43 KiB
# wheel                ------------------------------ 27.18 KiB/31.46 KiB
# ⠴ Preparing packages... (0/23)------------------     0 B/132.63 KiB
# gast                 ------------------------------     0 B/22.43 KiB
# wheel                ------------------------------ 27.18 KiB/31.46 KiB
# ⠴ Preparing packages... (0/23)------------------     0 B/132.63 KiB
# gast                 ------------------------------     0 B/22.43 KiB
# wheel                ------------------------------ 27.18 KiB/31.46 KiB
# ⠴ Preparing packages... (0/23)------------------     0 B/132.63 KiB
# gast                 ------------------------------     0 B/22.43 KiB
# wheel                ------------------------------ 27.18 KiB/31.46 KiB
# ⠴ Preparing packages... (0/23)------------------     0 B/132.63 KiB
# gast                 ------------------------------     0 B/22.43 KiB
# wheel                ------------------------------ 27.18 KiB/31.46 KiB
# absl-py              ------------------------------     0 B/132.63 KiB
# ⠴ Preparing packages... (0/23)------------------     0 B/1.32 MiB
# gast                 ------------------------------     0 B/22.43 KiB
# wheel                ------------------------------ 27.18 KiB/31.46 KiB
# absl-py              ------------------------------     0 B/132.63 KiB
# ⠴ Preparing packages... (0/23)------------------     0 B/1.32 MiB
# namex                   ------------------------------   579 B/5.77 KiB
# termcolor               ------------------------------ 2.46 KiB/7.50 KiB
# gast                    ------------------------------ 14.81 KiB/22.43 KiB
# wheel                   ------------------------------ 27.18 KiB/31.46 KiB
# google-pasta            ------------------------------ 3.70 KiB/56.12 KiB
# opt-einsum              ------------------------------     0 B/70.25 KiB
# markdown                ------------------------------     0 B/104.92 KiB
# absl-py                 ------------------------------     0 B/132.63 KiB
# werkzeug                ------------------------------     0 B/221.15 KiB
# ml-dtypes               ------------------------------     0 B/380.67 KiB
# protobuf                ------------------------------     0 B/385.57 KiB
# keras                   ------------------------------     0 B/1.32 MiB
# tensorboard-data-server ------------------------------     0 B/4.60 MiB
# tensorboard             ------------------------------     0 B/5.24 MiB
# grpcio                  ------------------------------     0 B/11.47 MiB
# ⠦ Preparing packages... (2/23)--------------------     0 B/19.68 MiB
# namex                   ------------------------------   579 B/5.77 KiB
# termcolor               ------------------------------ 2.46 KiB/7.50 KiB
# gast                    ------------------------------ 14.81 KiB/22.43 KiB
# wheel                   ------------------------------ 31.46 KiB/31.46 KiB
# google-pasta            ------------------------------ 3.70 KiB/56.12 KiB
# opt-einsum              ------------------------------ 14.83 KiB/70.25 KiB
# markdown                ------------------------------     0 B/104.92 KiB
# absl-py                 ------------------------------ 4.94 KiB/132.63 KiB
# werkzeug                ------------------------------     0 B/221.15 KiB
# ml-dtypes               ------------------------------     0 B/380.67 KiB
# protobuf                ------------------------------     0 B/385.57 KiB
# keras                   ------------------------------     0 B/1.32 MiB
# tensorboard-data-server ------------------------------     0 B/4.60 MiB
# tensorboard             ------------------------------     0 B/5.24 MiB
# grpcio                  ------------------------------     0 B/11.47 MiB
# ⠦ Preparing packages... (2/23)--------------------     0 B/19.68 MiB
# namex                   ------------------------------   579 B/5.77 KiB
# termcolor               ------------------------------ 2.46 KiB/7.50 KiB
# gast                    ------------------------------ 14.81 KiB/22.43 KiB
# google-pasta            ------------------------------ 3.70 KiB/56.12 KiB
# opt-einsum              ------------------------------ 14.83 KiB/70.25 KiB
# markdown                ------------------------------     0 B/104.92 KiB
# absl-py                 ------------------------------ 4.94 KiB/132.63 KiB
# werkzeug                ------------------------------     0 B/221.15 KiB
# ml-dtypes               ------------------------------     0 B/380.67 KiB
# protobuf                ------------------------------     0 B/385.57 KiB
# keras                   ------------------------------     0 B/1.32 MiB
# tensorboard-data-server ------------------------------     0 B/4.60 MiB
# tensorboard             ------------------------------     0 B/5.24 MiB
# grpcio                  ------------------------------     0 B/11.47 MiB
# numpy                   ------------------------------     0 B/19.68 MiB
# ⠦ Preparing packages... (2/23)--------------------     0 B/25.27 MiB
# namex                   ------------------------------   579 B/5.77 KiB
# termcolor               ------------------------------ 2.46 KiB/7.50 KiB
# gast                    ------------------------------ 14.81 KiB/22.43 KiB
# google-pasta            ------------------------------ 3.70 KiB/56.12 KiB
# opt-einsum              ------------------------------ 14.83 KiB/70.25 KiB
# markdown                ------------------------------ 16.00 KiB/104.92 KiB
# absl-py                 ------------------------------ 4.94 KiB/132.63 KiB
# werkzeug                ------------------------------     0 B/221.15 KiB
# ml-dtypes               ------------------------------     0 B/380.67 KiB
# protobuf                ------------------------------     0 B/385.57 KiB
# keras                   ------------------------------ 16.00 KiB/1.32 MiB
# tensorboard-data-server ------------------------------     0 B/4.60 MiB
# tensorboard             ------------------------------     0 B/5.24 MiB
# grpcio                  ------------------------------     0 B/11.47 MiB
# numpy                   ------------------------------     0 B/19.68 MiB
# ⠦ Preparing packages... (2/23)--------------------     0 B/25.27 MiB
# namex                   ------------------------------   579 B/5.77 KiB
# termcolor               ------------------------------ 2.46 KiB/7.50 KiB
# gast                    ------------------------------ 14.81 KiB/22.43 KiB
# google-pasta            ------------------------------ 3.70 KiB/56.12 KiB
# opt-einsum              ------------------------------ 14.83 KiB/70.25 KiB
# markdown                ------------------------------ 16.00 KiB/104.92 KiB
# absl-py                 ------------------------------ 4.94 KiB/132.63 KiB
# werkzeug                ------------------------------ 16.00 KiB/221.15 KiB
# ml-dtypes               ------------------------------     0 B/380.67 KiB
# protobuf                ------------------------------     0 B/385.57 KiB
# keras                   ------------------------------ 16.00 KiB/1.32 MiB
# tensorboard-data-server ------------------------------     0 B/4.60 MiB
# tensorboard             ------------------------------     0 B/5.24 MiB
# grpcio                  ------------------------------     0 B/11.47 MiB
# numpy                   ------------------------------     0 B/19.68 MiB
# ⠧ Preparing packages... (3/23)--------------------     0 B/25.27 MiB
# namex                   ------------------------------   579 B/5.77 KiB
# termcolor               ------------------------------ 2.46 KiB/7.50 KiB
# gast                    ------------------------------ 14.81 KiB/22.43 KiB
# google-pasta            ------------------------------ 3.70 KiB/56.12 KiB
# opt-einsum              ------------------------------ 14.83 KiB/70.25 KiB
# markdown                ------------------------------ 16.00 KiB/104.92 KiB
# absl-py                 ------------------------------ 4.94 KiB/132.63 KiB
# werkzeug                ------------------------------ 16.00 KiB/221.15 KiB
# ml-dtypes               ------------------------------     0 B/380.67 KiB
# protobuf                ------------------------------ 16.00 KiB/385.57 KiB
# keras                   ------------------------------ 16.00 KiB/1.32 MiB
# tensorboard-data-server ------------------------------     0 B/4.60 MiB
# tensorboard             ------------------------------     0 B/5.24 MiB
# grpcio                  ------------------------------     0 B/11.47 MiB
# numpy                   ------------------------------     0 B/19.68 MiB
# ⠧ Preparing packages... (3/23)--------------------     0 B/25.27 MiB
# namex                   ------------------------------   579 B/5.77 KiB
# termcolor               ------------------------------ 2.46 KiB/7.50 KiB
# gast                    ------------------------------ 14.81 KiB/22.43 KiB
# google-pasta            ------------------------------ 3.70 KiB/56.12 KiB
# opt-einsum              ------------------------------ 14.83 KiB/70.25 KiB
# markdown                ------------------------------ 16.00 KiB/104.92 KiB
# absl-py                 ------------------------------ 4.94 KiB/132.63 KiB
# werkzeug                ------------------------------ 16.00 KiB/221.15 KiB
# ml-dtypes               ------------------------------     0 B/380.67 KiB
# protobuf                ------------------------------ 16.00 KiB/385.57 KiB
# keras                   ------------------------------ 16.00 KiB/1.32 MiB
# tensorboard-data-server ------------------------------ 16.00 KiB/4.60 MiB
# tensorboard             ------------------------------     0 B/5.24 MiB
# grpcio                  ------------------------------     0 B/11.47 MiB
# numpy                   ------------------------------     0 B/19.68 MiB
# ⠧ Preparing packages... (3/23)--------------------     0 B/25.27 MiB
# namex                   ------------------------------   579 B/5.77 KiB
# termcolor               ------------------------------ 2.46 KiB/7.50 KiB
# gast                    ------------------------------ 14.81 KiB/22.43 KiB
# google-pasta            ------------------------------ 3.70 KiB/56.12 KiB
# opt-einsum              ------------------------------ 14.83 KiB/70.25 KiB
# markdown                ------------------------------ 16.00 KiB/104.92 KiB
# absl-py                 ------------------------------ 4.94 KiB/132.63 KiB
# werkzeug                ------------------------------ 16.00 KiB/221.15 KiB
# ml-dtypes               ------------------------------ 16.00 KiB/380.67 KiB
# protobuf                ------------------------------ 16.00 KiB/385.57 KiB
# keras                   ------------------------------ 16.00 KiB/1.32 MiB
# tensorboard-data-server ------------------------------ 16.00 KiB/4.60 MiB
# tensorboard             ------------------------------     0 B/5.24 MiB
# grpcio                  ------------------------------     0 B/11.47 MiB
# numpy                   ------------------------------     0 B/19.68 MiB
# ⠧ Preparing packages... (3/23)--------------------     0 B/25.27 MiB
# namex                   ------------------------------   579 B/5.77 KiB
# termcolor               ------------------------------ 2.46 KiB/7.50 KiB
# gast                    ------------------------------ 14.81 KiB/22.43 KiB
# google-pasta            ------------------------------ 3.70 KiB/56.12 KiB
# opt-einsum              ------------------------------ 14.83 KiB/70.25 KiB
# markdown                ------------------------------ 16.00 KiB/104.92 KiB
# absl-py                 ------------------------------ 4.94 KiB/132.63 KiB
# werkzeug                ------------------------------ 16.00 KiB/221.15 KiB
# ml-dtypes               ------------------------------ 16.00 KiB/380.67 KiB
# protobuf                ------------------------------ 16.00 KiB/385.57 KiB
# keras                   ------------------------------ 16.00 KiB/1.32 MiB
# tensorboard-data-server ------------------------------ 16.00 KiB/4.60 MiB
# tensorboard             ------------------------------ 16.00 KiB/5.24 MiB
# grpcio                  ------------------------------     0 B/11.47 MiB
# numpy                   ------------------------------     0 B/19.68 MiB
# ⠇ Preparing packages... (3/23)--------------------     0 B/25.27 MiB
# namex                   ------------------------------   579 B/5.77 KiB
# termcolor               ------------------------------ 2.46 KiB/7.50 KiB
# gast                    ------------------------------ 14.81 KiB/22.43 KiB
# google-pasta            ------------------------------ 3.70 KiB/56.12 KiB
# opt-einsum              ------------------------------ 14.83 KiB/70.25 KiB
# markdown                ------------------------------ 16.00 KiB/104.92 KiB
# absl-py                 ------------------------------ 4.94 KiB/132.63 KiB
# werkzeug                ------------------------------ 16.00 KiB/221.15 KiB
# ml-dtypes               ------------------------------ 16.00 KiB/380.67 KiB
# protobuf                ------------------------------ 16.00 KiB/385.57 KiB
# keras                   ------------------------------ 16.00 KiB/1.32 MiB
# tensorboard-data-server ------------------------------ 16.00 KiB/4.60 MiB
# tensorboard             ------------------------------ 16.00 KiB/5.24 MiB
# grpcio                  ------------------------------ 7.20 KiB/11.47 MiB
# numpy                   ------------------------------ 4.02 KiB/19.68 MiB
# ⠇ Preparing packages... (3/23)--------------------     0 B/25.27 MiB
# namex                        ------------------------------ 5.77 KiB/5.77 KiB
# termcolor                    ------------------------------ 7.50 KiB/7.50 KiB
# gast                         ------------------------------ 22.43 KiB/22.43 KiB
# google-pasta                 ------------------------------ 3.70 KiB/56.12 KiB
# opt-einsum                   ------------------------------ 14.83 KiB/70.25 KiB
# markdown                     ------------------------------ 16.00 KiB/104.92 KiB
# absl-py                      ------------------------------ 4.94 KiB/132.63 KiB
# werkzeug                     ------------------------------ 16.00 KiB/221.15 KiB
# ml-dtypes                    ------------------------------ 16.00 KiB/380.67 KiB
# protobuf                     ------------------------------ 16.00 KiB/385.57 KiB
# optree                       ------------------------------     0 B/389.24 KiB
# keras                        ------------------------------ 16.00 KiB/1.32 MiB
# tensorflow-io-gcs-filesystem ------------------------------     0 B/2.36 MiB
# tensorboard-data-server      ------------------------------ 16.00 KiB/4.60 MiB
# tensorboard                  ------------------------------ 16.00 KiB/5.24 MiB
# grpcio                       ------------------------------ 7.20 KiB/11.47 MiB
# numpy                        ------------------------------ 4.02 KiB/19.68 MiB
# libclang                     ------------------------------     0 B/25.27 MiB
# ⠇ Preparing packages... (3/23)-------------------------     0 B/247.52 MiB
# namex                        ------------------------------ 5.77 KiB/5.77 KiB
# termcolor                    ------------------------------ 7.50 KiB/7.50 KiB
# google-pasta                 ------------------------------ 14.75 KiB/56.12 KiB
# opt-einsum                   ------------------------------ 14.83 KiB/70.25 KiB
# markdown                     ------------------------------ 16.00 KiB/104.92 KiB
# absl-py                      ------------------------------ 4.94 KiB/132.63 KiB
# werkzeug                     ------------------------------ 16.00 KiB/221.15 KiB
# ml-dtypes                    ------------------------------ 16.00 KiB/380.67 KiB
# protobuf                     ------------------------------ 16.00 KiB/385.57 KiB
# optree                       ------------------------------     0 B/389.24 KiB
# keras                        ------------------------------ 16.00 KiB/1.32 MiB
# tensorflow-io-gcs-filesystem ------------------------------     0 B/2.36 MiB
# tensorboard-data-server      ------------------------------ 16.00 KiB/4.60 MiB
# tensorboard                  ------------------------------ 16.00 KiB/5.24 MiB
# grpcio                       ------------------------------ 7.20 KiB/11.47 MiB
# numpy                        ------------------------------ 4.02 KiB/19.68 MiB
# libclang                     ------------------------------     0 B/25.27 MiB
# ⠇ Preparing packages... (3/23)-------------------------     0 B/247.52 MiB
# termcolor                    ------------------------------ 7.50 KiB/7.50 KiB
# google-pasta                 ------------------------------ 14.75 KiB/56.12 KiB
# opt-einsum                   ------------------------------ 14.83 KiB/70.25 KiB
# markdown                     ------------------------------ 16.00 KiB/104.92 KiB
# absl-py                      ------------------------------ 4.94 KiB/132.63 KiB
# werkzeug                     ------------------------------ 16.00 KiB/221.15 KiB
# ml-dtypes                    ------------------------------ 16.00 KiB/380.67 KiB
# protobuf                     ------------------------------ 16.00 KiB/385.57 KiB
# optree                       ------------------------------     0 B/389.24 KiB
# keras                        ------------------------------ 16.00 KiB/1.32 MiB
# tensorflow-io-gcs-filesystem ------------------------------     0 B/2.36 MiB
# tensorboard-data-server      ------------------------------ 16.00 KiB/4.60 MiB
# tensorboard                  ------------------------------ 16.00 KiB/5.24 MiB
# grpcio                       ------------------------------ 7.20 KiB/11.47 MiB
# numpy                        ------------------------------ 4.02 KiB/19.68 MiB
# libclang                     ------------------------------     0 B/25.27 MiB
# ⠇ Preparing packages... (3/23)-------------------------     0 B/247.52 MiB
# google-pasta                 ------------------------------ 14.75 KiB/56.12 KiB
# opt-einsum                   ------------------------------ 14.83 KiB/70.25 KiB
# markdown                     ------------------------------ 16.00 KiB/104.92 KiB
# absl-py                      ------------------------------ 4.94 KiB/132.63 KiB
# werkzeug                     ------------------------------ 16.00 KiB/221.15 KiB
# ml-dtypes                    ------------------------------ 16.00 KiB/380.67 KiB
# protobuf                     ------------------------------ 16.00 KiB/385.57 KiB
# optree                       ------------------------------     0 B/389.24 KiB
# keras                        ------------------------------ 16.00 KiB/1.32 MiB
# tensorflow-io-gcs-filesystem ------------------------------     0 B/2.36 MiB
# tensorboard-data-server      ------------------------------ 16.00 KiB/4.60 MiB
# tensorboard                  ------------------------------ 16.00 KiB/5.24 MiB
# grpcio                       ------------------------------ 7.20 KiB/11.47 MiB
# numpy                        ------------------------------ 4.02 KiB/19.68 MiB
# libclang                     ------------------------------     0 B/25.27 MiB
# ⠇ Preparing packages... (3/23)-------------------------     0 B/247.52 MiB
# google-pasta                 ------------------------------ 14.75 KiB/56.12 KiB
# opt-einsum                   ------------------------------ 14.83 KiB/70.25 KiB
# markdown                     ------------------------------ 16.00 KiB/104.92 KiB
# absl-py                      ------------------------------ 20.94 KiB/132.63 KiB
# werkzeug                     ------------------------------ 16.00 KiB/221.15 KiB
# ml-dtypes                    ------------------------------ 16.00 KiB/380.67 KiB
# protobuf                     ------------------------------ 16.00 KiB/385.57 KiB
# optree                       ------------------------------     0 B/389.24 KiB
# keras                        ------------------------------ 16.00 KiB/1.32 MiB
# tensorflow-io-gcs-filesystem ------------------------------ 14.81 KiB/2.36 MiB
# tensorboard-data-server      ------------------------------ 16.00 KiB/4.60 MiB
# tensorboard                  ------------------------------ 16.00 KiB/5.24 MiB
# grpcio                       ------------------------------ 7.20 KiB/11.47 MiB
# numpy                        ------------------------------ 4.02 KiB/19.68 MiB
# libclang                     ------------------------------ 16.00 KiB/25.27 MiB
# ⠇ Preparing packages... (3/23)-------------------------     0 B/247.52 MiB
# google-pasta                 ------------------------------ 14.75 KiB/56.12 KiB
# opt-einsum                   ------------------------------ 14.83 KiB/70.25 KiB
# markdown                     ------------------------------ 16.00 KiB/104.92 KiB
# absl-py                      ------------------------------ 20.94 KiB/132.63 KiB
# werkzeug                     ------------------------------ 16.00 KiB/221.15 KiB
# ml-dtypes                    ------------------------------ 16.00 KiB/380.67 KiB
# protobuf                     ------------------------------ 16.00 KiB/385.57 KiB
# optree                       ------------------------------     0 B/389.24 KiB
# keras                        ------------------------------ 32.00 KiB/1.32 MiB
# tensorflow-io-gcs-filesystem ------------------------------ 14.81 KiB/2.36 MiB
# tensorboard-data-server      ------------------------------ 16.00 KiB/4.60 MiB
# tensorboard                  ------------------------------ 16.00 KiB/5.24 MiB
# grpcio                       ------------------------------ 7.20 KiB/11.47 MiB
# numpy                        ------------------------------ 4.02 KiB/19.68 MiB
# libclang                     ------------------------------ 16.00 KiB/25.27 MiB
# ⠇ Preparing packages... (3/23)-------------------------     0 B/247.52 MiB
# google-pasta                 ------------------------------ 14.75 KiB/56.12 KiB
# opt-einsum                   ------------------------------ 14.83 KiB/70.25 KiB
# markdown                     ------------------------------ 32.00 KiB/104.92 KiB
# absl-py                      ------------------------------ 20.94 KiB/132.63 KiB
# werkzeug                     ------------------------------ 32.00 KiB/221.15 KiB
# ml-dtypes                    ------------------------------ 16.00 KiB/380.67 KiB
# protobuf                     ------------------------------ 16.00 KiB/385.57 KiB
# optree                       ------------------------------     0 B/389.24 KiB
# keras                        ------------------------------ 32.00 KiB/1.32 MiB
# tensorflow-io-gcs-filesystem ------------------------------ 14.81 KiB/2.36 MiB
# tensorboard-data-server      ------------------------------ 16.00 KiB/4.60 MiB
# tensorboard                  ------------------------------ 16.00 KiB/5.24 MiB
# grpcio                       ------------------------------ 7.20 KiB/11.47 MiB
# numpy                        ------------------------------ 4.02 KiB/19.68 MiB
# libclang                     ------------------------------ 16.00 KiB/25.27 MiB
# ⠋ Preparing packages... (6/23)-------------------------     0 B/247.52 MiB
# google-pasta                 ------------------------------ 14.75 KiB/56.12 KiB
# opt-einsum                   ------------------------------ 14.83 KiB/70.25 KiB
# markdown                     ------------------------------ 32.00 KiB/104.92 KiB
# absl-py                      ------------------------------ 20.94 KiB/132.63 KiB
# werkzeug                     ------------------------------ 32.00 KiB/221.15 KiB
# ml-dtypes                    ------------------------------ 16.00 KiB/380.67 KiB
# protobuf                     ------------------------------ 32.00 KiB/385.57 KiB
# optree                       ------------------------------     0 B/389.24 KiB
# keras                        ------------------------------ 32.00 KiB/1.32 MiB
# tensorflow-io-gcs-filesystem ------------------------------ 14.81 KiB/2.36 MiB
# h5py                         ------------------------------     0 B/3.19 MiB
# tensorboard-data-server      ------------------------------ 18.50 KiB/4.60 MiB
# tensorboard                  ------------------------------ 16.00 KiB/5.24 MiB
# grpcio                       ------------------------------ 16.00 KiB/11.47 MiB
# numpy                        ------------------------------ 4.02 KiB/19.68 MiB
# libclang                     ------------------------------ 16.00 KiB/25.27 MiB
# ⠋ Preparing packages... (6/23)-------------------------     0 B/247.52 MiB
# google-pasta                 ------------------------------ 14.75 KiB/56.12 KiB
# opt-einsum                   ------------------------------ 14.83 KiB/70.25 KiB
# markdown                     ------------------------------ 32.00 KiB/104.92 KiB
# absl-py                      ------------------------------ 20.94 KiB/132.63 KiB
# werkzeug                     ------------------------------ 32.00 KiB/221.15 KiB
# ml-dtypes                    ------------------------------ 32.00 KiB/380.67 KiB
# protobuf                     ------------------------------ 32.00 KiB/385.57 KiB
# optree                       ------------------------------     0 B/389.24 KiB
# keras                        ------------------------------ 32.00 KiB/1.32 MiB
# tensorflow-io-gcs-filesystem ------------------------------ 14.81 KiB/2.36 MiB
# h5py                         ------------------------------     0 B/3.19 MiB
# tensorboard-data-server      ------------------------------ 18.50 KiB/4.60 MiB
# tensorboard                  ------------------------------ 16.00 KiB/5.24 MiB
# grpcio                       ------------------------------ 16.00 KiB/11.47 MiB
# numpy                        ------------------------------ 4.02 KiB/19.68 MiB
# libclang                     ------------------------------ 16.00 KiB/25.27 MiB
# ⠋ Preparing packages... (6/23)-------------------------     0 B/247.52 MiB
# google-pasta                 ------------------------------ 14.75 KiB/56.12 KiB
# opt-einsum                   ------------------------------ 14.83 KiB/70.25 KiB
# markdown                     ------------------------------ 32.00 KiB/104.92 KiB
# absl-py                      ------------------------------ 20.94 KiB/132.63 KiB
# werkzeug                     ------------------------------ 32.00 KiB/221.15 KiB
# ml-dtypes                    ------------------------------ 32.00 KiB/380.67 KiB
# protobuf                     ------------------------------ 32.00 KiB/385.57 KiB
# optree                       ------------------------------     0 B/389.24 KiB
# keras                        ------------------------------ 32.00 KiB/1.32 MiB
# tensorflow-io-gcs-filesystem ------------------------------ 14.81 KiB/2.36 MiB
# h5py                         ------------------------------     0 B/3.19 MiB
# tensorboard-data-server      ------------------------------ 18.50 KiB/4.60 MiB
# tensorboard                  ------------------------------ 32.00 KiB/5.24 MiB
# grpcio                       ------------------------------ 16.00 KiB/11.47 MiB
# numpy                        ------------------------------ 4.02 KiB/19.68 MiB
# libclang                     ------------------------------ 16.00 KiB/25.27 MiB
# ⠋ Preparing packages... (6/23)-------------------------     0 B/247.52 MiB
# google-pasta                 ------------------------------ 14.75 KiB/56.12 KiB
# opt-einsum                   ------------------------------ 14.83 KiB/70.25 KiB
# markdown                     ------------------------------ 32.00 KiB/104.92 KiB
# absl-py                      ------------------------------ 36.94 KiB/132.63 KiB
# werkzeug                     ------------------------------ 32.00 KiB/221.15 KiB
# ml-dtypes                    ------------------------------ 32.00 KiB/380.67 KiB
# protobuf                     ------------------------------ 32.00 KiB/385.57 KiB
# optree                       ------------------------------     0 B/389.24 KiB
# keras                        ------------------------------ 32.00 KiB/1.32 MiB
# tensorflow-io-gcs-filesystem ------------------------------ 14.81 KiB/2.36 MiB
# h5py                         ------------------------------     0 B/3.19 MiB
# tensorboard-data-server      ------------------------------ 18.50 KiB/4.60 MiB
# tensorboard                  ------------------------------ 32.00 KiB/5.24 MiB
# grpcio                       ------------------------------ 16.00 KiB/11.47 MiB
# numpy                        ------------------------------ 20.02 KiB/19.68 MiB
# libclang                     ------------------------------ 16.00 KiB/25.27 MiB
# ⠙ Preparing packages... (6/23)-------------------------     0 B/247.52 MiB
# google-pasta                 ------------------------------ 14.75 KiB/56.12 KiB
# opt-einsum                   ------------------------------ 14.83 KiB/70.25 KiB
# markdown                     ------------------------------ 32.00 KiB/104.92 KiB
# absl-py                      ------------------------------ 36.94 KiB/132.63 KiB
# werkzeug                     ------------------------------ 32.00 KiB/221.15 KiB
# ml-dtypes                    ------------------------------ 32.00 KiB/380.67 KiB
# protobuf                     ------------------------------ 32.00 KiB/385.57 KiB
# optree                       ------------------------------ 7.91 KiB/389.24 KiB
# keras                        ------------------------------ 32.00 KiB/1.32 MiB
# tensorflow-io-gcs-filesystem ------------------------------ 14.81 KiB/2.36 MiB
# h5py                         ------------------------------ 14.83 KiB/3.19 MiB
# tensorboard-data-server      ------------------------------ 18.50 KiB/4.60 MiB
# tensorboard                  ------------------------------ 32.00 KiB/5.24 MiB
# grpcio                       ------------------------------ 16.00 KiB/11.47 MiB
# numpy                        ------------------------------ 20.02 KiB/19.68 MiB
# libclang                     ------------------------------ 32.00 KiB/25.27 MiB
# ⠙ Preparing packages... (6/23)------------------------- 16.00 KiB/247.52 MiB
# google-pasta                 ------------------------------ 14.75 KiB/56.12 KiB
# opt-einsum                   ------------------------------ 14.83 KiB/70.25 KiB
# markdown                     ------------------------------ 32.00 KiB/104.92 KiB
# absl-py                      ------------------------------ 36.94 KiB/132.63 KiB
# werkzeug                     ------------------------------ 32.00 KiB/221.15 KiB
# ml-dtypes                    ------------------------------ 32.00 KiB/380.67 KiB
# protobuf                     ------------------------------ 32.00 KiB/385.57 KiB
# optree                       ------------------------------ 7.91 KiB/389.24 KiB
# keras                        ------------------------------ 48.00 KiB/1.32 MiB
# tensorflow-io-gcs-filesystem ------------------------------ 14.81 KiB/2.36 MiB
# h5py                         ------------------------------ 14.83 KiB/3.19 MiB
# tensorboard-data-server      ------------------------------ 18.50 KiB/4.60 MiB
# tensorboard                  ------------------------------ 32.00 KiB/5.24 MiB
# grpcio                       ------------------------------ 16.00 KiB/11.47 MiB
# numpy                        ------------------------------ 20.02 KiB/19.68 MiB
# libclang                     ------------------------------ 32.00 KiB/25.27 MiB
# ⠙ Preparing packages... (6/23)------------------------- 16.00 KiB/247.52 MiB
# google-pasta                 ------------------------------ 14.75 KiB/56.12 KiB
# opt-einsum                   ------------------------------ 14.83 KiB/70.25 KiB
# markdown                     ------------------------------ 32.00 KiB/104.92 KiB
# absl-py                      ------------------------------ 36.94 KiB/132.63 KiB
# werkzeug                     ------------------------------ 48.00 KiB/221.15 KiB
# ml-dtypes                    ------------------------------ 32.00 KiB/380.67 KiB
# protobuf                     ------------------------------ 32.00 KiB/385.57 KiB
# optree                       ------------------------------ 7.91 KiB/389.24 KiB
# keras                        ------------------------------ 48.00 KiB/1.32 MiB
# tensorflow-io-gcs-filesystem ------------------------------ 14.81 KiB/2.36 MiB
# h5py                         ------------------------------ 14.83 KiB/3.19 MiB
# tensorboard-data-server      ------------------------------ 18.50 KiB/4.60 MiB
# tensorboard                  ------------------------------ 32.00 KiB/5.24 MiB
# grpcio                       ------------------------------ 16.00 KiB/11.47 MiB
# numpy                        ------------------------------ 20.02 KiB/19.68 MiB
# libclang                     ------------------------------ 32.00 KiB/25.27 MiB
# ⠹ Preparing packages... (6/23)------------------------- 16.00 KiB/247.52 MiB
# google-pasta                 ------------------------------ 30.75 KiB/56.12 KiB
# opt-einsum                   ------------------------------ 14.83 KiB/70.25 KiB
# markdown                     ------------------------------ 32.00 KiB/104.92 KiB
# absl-py                      ------------------------------ 36.94 KiB/132.63 KiB
# werkzeug                     ------------------------------ 48.00 KiB/221.15 KiB
# ml-dtypes                    ------------------------------ 32.00 KiB/380.67 KiB
# protobuf                     ------------------------------ 32.00 KiB/385.57 KiB
# optree                       ------------------------------ 7.91 KiB/389.24 KiB
# keras                        ------------------------------ 48.00 KiB/1.32 MiB
# tensorflow-io-gcs-filesystem ------------------------------ 14.81 KiB/2.36 MiB
# h5py                         ------------------------------ 14.83 KiB/3.19 MiB
# tensorboard-data-server      ------------------------------ 32.00 KiB/4.60 MiB
# tensorboard                  ------------------------------ 32.00 KiB/5.24 MiB
# grpcio                       ------------------------------ 16.00 KiB/11.47 MiB
# numpy                        ------------------------------ 20.02 KiB/19.68 MiB
# libclang                     ------------------------------ 32.00 KiB/25.27 MiB
# ⠹ Preparing packages... (6/23)------------------------- 16.00 KiB/247.52 MiB
# google-pasta                 ------------------------------ 30.75 KiB/56.12 KiB
# opt-einsum                   ------------------------------ 30.83 KiB/70.25 KiB
# markdown                     ------------------------------ 32.00 KiB/104.92 KiB
# absl-py                      ------------------------------ 36.94 KiB/132.63 KiB
# werkzeug                     ------------------------------ 48.00 KiB/221.15 KiB
# ml-dtypes                    ------------------------------ 32.00 KiB/380.67 KiB
# protobuf                     ------------------------------ 32.00 KiB/385.57 KiB
# optree                       ------------------------------ 7.91 KiB/389.24 KiB
# keras                        ------------------------------ 48.00 KiB/1.32 MiB
# tensorflow-io-gcs-filesystem ------------------------------ 30.81 KiB/2.36 MiB
# h5py                         ------------------------------ 14.83 KiB/3.19 MiB
# tensorboard-data-server      ------------------------------ 32.00 KiB/4.60 MiB
# tensorboard                  ------------------------------ 32.00 KiB/5.24 MiB
# grpcio                       ------------------------------ 16.00 KiB/11.47 MiB
# numpy                        ------------------------------ 20.02 KiB/19.68 MiB
# libclang                     ------------------------------ 32.00 KiB/25.27 MiB
# ⠹ Preparing packages... (6/23)------------------------- 16.00 KiB/247.52 MiB
# google-pasta                 ------------------------------ 30.75 KiB/56.12 KiB
# opt-einsum                   ------------------------------ 30.83 KiB/70.25 KiB
# markdown                     ------------------------------ 48.00 KiB/104.92 KiB
# absl-py                      ------------------------------ 36.94 KiB/132.63 KiB
# werkzeug                     ------------------------------ 48.00 KiB/221.15 KiB
# ml-dtypes                    ------------------------------ 32.00 KiB/380.67 KiB
# protobuf                     ------------------------------ 32.00 KiB/385.57 KiB
# optree                       ------------------------------ 7.91 KiB/389.24 KiB
# keras                        ------------------------------ 48.00 KiB/1.32 MiB
# tensorflow-io-gcs-filesystem ------------------------------ 30.81 KiB/2.36 MiB
# h5py                         ------------------------------ 14.83 KiB/3.19 MiB
# tensorboard-data-server      ------------------------------ 32.00 KiB/4.60 MiB
# tensorboard                  ------------------------------ 32.00 KiB/5.24 MiB
# grpcio                       ------------------------------ 16.00 KiB/11.47 MiB
# numpy                        ------------------------------ 20.02 KiB/19.68 MiB
# libclang                     ------------------------------ 32.00 KiB/25.27 MiB
# ⠹ Preparing packages... (6/23)------------------------- 16.00 KiB/247.52 MiB
# google-pasta                 ------------------------------ 30.75 KiB/56.12 KiB
# opt-einsum                   ------------------------------ 30.83 KiB/70.25 KiB
# markdown                     ------------------------------ 48.00 KiB/104.92 KiB
# absl-py                      ------------------------------ 36.94 KiB/132.63 KiB
# werkzeug                     ------------------------------ 48.00 KiB/221.15 KiB
# ml-dtypes                    ------------------------------ 48.00 KiB/380.67 KiB
# protobuf                     ------------------------------ 34.39 KiB/385.57 KiB
# optree                       ------------------------------ 7.91 KiB/389.24 KiB
# keras                        ------------------------------ 48.00 KiB/1.32 MiB
# tensorflow-io-gcs-filesystem ------------------------------ 30.81 KiB/2.36 MiB
# h5py                         ------------------------------ 14.83 KiB/3.19 MiB
# tensorboard-data-server      ------------------------------ 32.00 KiB/4.60 MiB
# tensorboard                  ------------------------------ 48.00 KiB/5.24 MiB
# grpcio                       ------------------------------ 16.00 KiB/11.47 MiB
# numpy                        ------------------------------ 20.02 KiB/19.68 MiB
# libclang                     ------------------------------ 32.00 KiB/25.27 MiB
# ⠹ Preparing packages... (6/23)------------------------- 16.00 KiB/247.52 MiB
# google-pasta                 ------------------------------ 30.75 KiB/56.12 KiB
# opt-einsum                   ------------------------------ 30.83 KiB/70.25 KiB
# markdown                     ------------------------------ 48.00 KiB/104.92 KiB
# absl-py                      ------------------------------ 52.94 KiB/132.63 KiB
# werkzeug                     ------------------------------ 48.00 KiB/221.15 KiB
# ml-dtypes                    ------------------------------ 48.00 KiB/380.67 KiB
# protobuf                     ------------------------------ 34.39 KiB/385.57 KiB
# optree                       ------------------------------ 7.91 KiB/389.24 KiB
# keras                        ------------------------------ 48.00 KiB/1.32 MiB
# tensorflow-io-gcs-filesystem ------------------------------ 30.81 KiB/2.36 MiB
# h5py                         ------------------------------ 14.83 KiB/3.19 MiB
# tensorboard-data-server      ------------------------------ 32.00 KiB/4.60 MiB
# tensorboard                  ------------------------------ 48.00 KiB/5.24 MiB
# grpcio                       ------------------------------ 16.00 KiB/11.47 MiB
# numpy                        ------------------------------ 24.10 KiB/19.68 MiB
# libclang                     ------------------------------ 32.00 KiB/25.27 MiB
# ⠸ Preparing packages... (6/23)------------------------- 16.00 KiB/247.52 MiB
# google-pasta                 ------------------------------ 30.75 KiB/56.12 KiB
# opt-einsum                   ------------------------------ 30.83 KiB/70.25 KiB
# markdown                     ------------------------------ 48.00 KiB/104.92 KiB
# absl-py                      ------------------------------ 52.94 KiB/132.63 KiB
# werkzeug                     ------------------------------ 64.00 KiB/221.15 KiB
# ml-dtypes                    ------------------------------ 48.00 KiB/380.67 KiB
# protobuf                     ------------------------------ 34.39 KiB/385.57 KiB
# optree                       ------------------------------ 23.91 KiB/389.24 KiB
# keras                        ------------------------------ 59.80 KiB/1.32 MiB
# tensorflow-io-gcs-filesystem ------------------------------ 30.81 KiB/2.36 MiB
# h5py                         ------------------------------ 30.83 KiB/3.19 MiB
# tensorboard-data-server      ------------------------------ 32.00 KiB/4.60 MiB
# tensorboard                  ------------------------------ 48.00 KiB/5.24 MiB
# grpcio                       ------------------------------ 32.00 KiB/11.47 MiB
# numpy                        ------------------------------ 24.10 KiB/19.68 MiB
# libclang                     ------------------------------ 48.00 KiB/25.27 MiB
# ⠸ Preparing packages... (6/23)------------------------- 16.00 KiB/247.52 MiB
# google-pasta                 ------------------------------ 46.75 KiB/56.12 KiB
# opt-einsum                   ------------------------------ 30.83 KiB/70.25 KiB
# markdown                     ------------------------------ 48.00 KiB/104.92 KiB
# absl-py                      ------------------------------ 52.94 KiB/132.63 KiB
# werkzeug                     ------------------------------ 64.00 KiB/221.15 KiB
# ml-dtypes                    ------------------------------ 48.00 KiB/380.67 KiB
# protobuf                     ------------------------------ 34.39 KiB/385.57 KiB
# optree                       ------------------------------ 23.91 KiB/389.24 KiB
# keras                        ------------------------------ 59.80 KiB/1.32 MiB
# tensorflow-io-gcs-filesystem ------------------------------ 30.81 KiB/2.36 MiB
# h5py                         ------------------------------ 30.83 KiB/3.19 MiB
# tensorboard-data-server      ------------------------------ 32.00 KiB/4.60 MiB
# tensorboard                  ------------------------------ 48.00 KiB/5.24 MiB
# grpcio                       ------------------------------ 32.00 KiB/11.47 MiB
# numpy                        ------------------------------ 24.10 KiB/19.68 MiB
# libclang                     ------------------------------ 48.00 KiB/25.27 MiB
# ⠸ Preparing packages... (6/23)------------------------- 16.00 KiB/247.52 MiB
# google-pasta                 ------------------------------ 46.75 KiB/56.12 KiB
# opt-einsum                   ------------------------------ 46.83 KiB/70.25 KiB
# markdown                     ------------------------------ 64.00 KiB/104.92 KiB
# absl-py                      ------------------------------ 52.94 KiB/132.63 KiB
# werkzeug                     ------------------------------ 64.00 KiB/221.15 KiB
# ml-dtypes                    ------------------------------ 48.00 KiB/380.67 KiB
# protobuf                     ------------------------------ 34.39 KiB/385.57 KiB
# optree                       ------------------------------ 23.91 KiB/389.24 KiB
# keras                        ------------------------------ 59.80 KiB/1.32 MiB
# tensorflow-io-gcs-filesystem ------------------------------ 46.81 KiB/2.36 MiB
# h5py                         ------------------------------ 30.83 KiB/3.19 MiB
# tensorboard-data-server      ------------------------------ 32.00 KiB/4.60 MiB
# tensorboard                  ------------------------------ 48.00 KiB/5.24 MiB
# grpcio                       ------------------------------ 32.00 KiB/11.47 MiB
# numpy                        ------------------------------ 24.10 KiB/19.68 MiB
# libclang                     ------------------------------ 48.00 KiB/25.27 MiB
# ⠸ Preparing packages... (6/23)------------------------- 16.00 KiB/247.52 MiB
# google-pasta                 ------------------------------ 46.75 KiB/56.12 KiB
# opt-einsum                   ------------------------------ 46.83 KiB/70.25 KiB
# markdown                     ------------------------------ 64.00 KiB/104.92 KiB
# absl-py                      ------------------------------ 52.94 KiB/132.63 KiB
# werkzeug                     ------------------------------ 64.00 KiB/221.15 KiB
# ...
# libclang                     ------------------------------ 1.44 MiB/25.27 MiB
# ⠴ Preparing packages... (15/23)------------------------- 1.41 MiB/247.52 MiB
# tensorflow-io-gcs-filesystem ------------------------------ 1.38 MiB/2.36 MiB
# h5py                         ------------------------------ 1.38 MiB/3.19 MiB
# tensorboard-data-server      ------------------------------ 1.38 MiB/4.60 MiB
# tensorboard                  ------------------------------ 1.34 MiB/5.24 MiB
# grpcio                       ------------------------------ 1.38 MiB/11.47 MiB
# numpy                        ------------------------------ 1.29 MiB/19.68 MiB
# libclang                     ------------------------------ 1.44 MiB/25.27 MiB
# ⠴ Preparing packages... (15/23)------------------------- 1.41 MiB/247.52 MiB
# tensorflow-io-gcs-filesystem ------------------------------ 1.38 MiB/2.36 MiB
# h5py                         ------------------------------ 1.38 MiB/3.19 MiB
# tensorboard-data-server      ------------------------------ 1.38 MiB/4.60 MiB
# tensorboard                  ------------------------------ 1.34 MiB/5.24 MiB
# grpcio                       ------------------------------ 1.39 MiB/11.47 MiB
# numpy                        ------------------------------ 1.29 MiB/19.68 MiB
# libclang                     ------------------------------ 1.44 MiB/25.27 MiB
# ⠴ Preparing packages... (15/23)------------------------- 1.41 MiB/247.52 MiB
# tensorflow-io-gcs-filesystem ------------------------------ 1.38 MiB/2.36 MiB
# h5py                         ------------------------------ 1.38 MiB/3.19 MiB
# tensorboard-data-server      ------------------------------ 1.39 MiB/4.60 MiB
# tensorboard                  ------------------------------ 1.34 MiB/5.24 MiB
# grpcio                       ------------------------------ 1.39 MiB/11.47 MiB
# numpy                        ------------------------------ 1.29 MiB/19.68 MiB
# libclang                     ------------------------------ 1.44 MiB/25.27 MiB
# ⠴ Preparing packages... (15/23)------------------------- 1.41 MiB/247.52 MiB
# tensorflow-io-gcs-filesystem ------------------------------ 1.38 MiB/2.36 MiB
# h5py                         ------------------------------ 1.38 MiB/3.19 MiB
# tensorboard-data-server      ------------------------------ 1.39 MiB/4.60 MiB
# tensorboard                  ------------------------------ 1.36 MiB/5.24 MiB
# grpcio                       ------------------------------ 1.39 MiB/11.47 MiB
# numpy                        ------------------------------ 1.29 MiB/19.68 MiB
# libclang                     ------------------------------ 1.44 MiB/25.27 MiB
# ⠴ Preparing packages... (15/23)------------------------- 1.41 MiB/247.52 MiB
# tensorflow-io-gcs-filesystem ------------------------------ 1.38 MiB/2.36 MiB
# h5py                         ------------------------------ 1.38 MiB/3.19 MiB
# tensorboard-data-server      ------------------------------ 1.39 MiB/4.60 MiB
# tensorboard                  ------------------------------ 1.36 MiB/5.24 MiB
# grpcio                       ------------------------------ 1.39 MiB/11.47 MiB
# numpy                        ------------------------------ 1.29 MiB/19.68 MiB
# libclang                     ------------------------------ 1.44 MiB/25.27 MiB
# ⠴ Preparing packages... (15/23)------------------------- 1.42 MiB/247.52 MiB
# tensorflow-io-gcs-filesystem ------------------------------ 1.38 MiB/2.36 MiB
# h5py                         ------------------------------ 1.38 MiB/3.19 MiB
# tensorboard-data-server      ------------------------------ 1.39 MiB/4.60 MiB
# tensorboard                  ------------------------------ 1.36 MiB/5.24 MiB
# grpcio                       ------------------------------ 1.39 MiB/11.47 MiB
# numpy                        ------------------------------ 1.29 MiB/19.68 MiB
# libclang                     ------------------------------ 1.45 MiB/25.27 MiB
# ⠴ Preparing packages... (15/23)------------------------- 1.42 MiB/247.52 MiB
# tensorflow-io-gcs-filesystem ------------------------------ 1.38 MiB/2.36 MiB
# h5py                         ------------------------------ 1.38 MiB/3.19 MiB
# tensorboard-data-server      ------------------------------ 1.39 MiB/4.60 MiB
# tensorboard                  ------------------------------ 1.36 MiB/5.24 MiB
# grpcio                       ------------------------------ 1.39 MiB/11.47 MiB
# numpy                        ------------------------------ 1.29 MiB/19.68 MiB
# libclang                     ------------------------------ 1.45 MiB/25.27 MiB
# ⠦ Preparing packages... (15/23)------------------------- 1.42 MiB/247.52 MiB
# tensorflow-io-gcs-filesystem ------------------------------ 1.38 MiB/2.36 MiB
# h5py                         ------------------------------ 1.38 MiB/3.19 MiB
# tensorboard-data-server      ------------------------------ 1.39 MiB/4.60 MiB
# tensorboard                  ------------------------------ 1.36 MiB/5.24 MiB
# grpcio                       ------------------------------ 1.39 MiB/11.47 MiB
# numpy                        ------------------------------ 1.29 MiB/19.68 MiB
# libclang                     ------------------------------ 1.45 MiB/25.27 MiB
# ⠦ Preparing packages... (15/23)------------------------- 1.42 MiB/247.52 MiB
# tensorflow-io-gcs-filesystem ------------------------------ 1.38 MiB/2.36 MiB
# h5py                         ------------------------------ 1.38 MiB/3.19 MiB
# tensorboard-data-server      ------------------------------ 1.39 MiB/4.60 MiB
# tensorboard                  ------------------------------ 1.36 MiB/5.24 MiB
# grpcio                       ------------------------------ 1.39 MiB/11.47 MiB
# numpy                        ------------------------------ 1.31 MiB/19.68 MiB
# libclang                     ------------------------------ 1.45 MiB/25.27 MiB
# ⠦ Preparing packages... (15/23)------------------------- 1.42 MiB/247.52 MiB
# tensorflow-io-gcs-filesystem ------------------------------ 1.38 MiB/2.36 MiB
# h5py                         ------------------------------ 1.38 MiB/3.19 MiB
# tensorboard-data-server      ------------------------------ 1.39 MiB/4.60 MiB
# tensorboard                  ------------------------------ 1.36 MiB/5.24 MiB
# grpcio                       ------------------------------ 1.39 MiB/11.47 MiB
# numpy                        ------------------------------ 1.31 MiB/19.68 MiB
# libclang                     ------------------------------ 1.45 MiB/25.27 MiB
# ⠧ Preparing packages... (15/23)------------------------- 1.43 MiB/247.52 MiB
# tensorflow-io-gcs-filesystem ------------------------------ 1.38 MiB/2.36 MiB
# h5py                         ------------------------------ 1.38 MiB/3.19 MiB
# tensorboard-data-server      ------------------------------ 1.39 MiB/4.60 MiB
# tensorboard                  ------------------------------ 1.36 MiB/5.24 MiB
# grpcio                       ------------------------------ 1.39 MiB/11.47 MiB
# numpy                        ------------------------------ 1.31 MiB/19.68 MiB
# libclang                     ------------------------------ 1.45 MiB/25.27 MiB
# ⠧ Preparing packages... (15/23)------------------------- 1.43 MiB/247.52 MiB
# tensorflow-io-gcs-filesystem ------------------------------ 1.38 MiB/2.36 MiB
# h5py                         ------------------------------ 1.38 MiB/3.19 MiB
# tensorboard-data-server      ------------------------------ 1.41 MiB/4.60 MiB
# tensorboard                  ------------------------------ 1.36 MiB/5.24 MiB
# grpcio                       ------------------------------ 1.39 MiB/11.47 MiB
# numpy                        ------------------------------ 1.31 MiB/19.68 MiB
# libclang                     ------------------------------ 1.45 MiB/25.27 MiB
# ⠇ Preparing packages... (15/23)------------------------- 1.43 MiB/247.52 MiB
# tensorflow-io-gcs-filesystem ------------------------------ 1.38 MiB/2.36 MiB
# h5py                         ------------------------------ 1.38 MiB/3.19 MiB
# tensorboard-data-server      ------------------------------ 1.41 MiB/4.60 MiB
# tensorboard                  ------------------------------ 1.36 MiB/5.24 MiB
# grpcio                       ------------------------------ 1.39 MiB/11.47 MiB
# numpy                        ------------------------------ 1.31 MiB/19.68 MiB
# libclang                     ------------------------------ 1.45 MiB/25.27 MiB
# ⠋ Preparing packages... (15/23)------------------------- 1.43 MiB/247.52 MiB
# tensorflow-io-gcs-filesystem ------------------------------ 1.38 MiB/2.36 MiB
# h5py                         ------------------------------ 1.38 MiB/3.19 MiB
# tensorboard-data-server      ------------------------------ 1.41 MiB/4.60 MiB
# tensorboard                  ------------------------------ 1.36 MiB/5.24 MiB
# grpcio                       ------------------------------ 1.39 MiB/11.47 MiB
# numpy                        ------------------------------ 1.31 MiB/19.68 MiB
# libclang                     ------------------------------ 1.45 MiB/25.27 MiB
# ⠙ Preparing packages... (15/23)------------------------- 1.43 MiB/247.52 MiB
# tensorflow-io-gcs-filesystem ------------------------------ 1.38 MiB/2.36 MiB
# h5py                         ------------------------------ 1.38 MiB/3.19 MiB
# tensorboard-data-server      ------------------------------ 1.41 MiB/4.60 MiB
# tensorboard                  ------------------------------ 1.36 MiB/5.24 MiB
# grpcio                       ------------------------------ 1.39 MiB/11.47 MiB
# numpy                        ------------------------------ 1.31 MiB/19.68 MiB
# libclang                     ------------------------------ 1.45 MiB/25.27 MiB
# ⠹ Preparing packages... (15/23)------------------------- 1.43 MiB/247.52 MiB
# tensorflow-io-gcs-filesystem ------------------------------ 1.38 MiB/2.36 MiB
# h5py                         ------------------------------ 1.38 MiB/3.19 MiB
# tensorboard-data-server      ------------------------------ 1.41 MiB/4.60 MiB
# tensorboard                  ------------------------------ 1.36 MiB/5.24 MiB
# grpcio                       ------------------------------ 1.39 MiB/11.47 MiB
# numpy                        ------------------------------ 1.31 MiB/19.68 MiB
# libclang                     ------------------------------ 1.45 MiB/25.27 MiB
# ⠹ Preparing packages... (15/23)------------------------- 1.43 MiB/247.52 MiB
# tensorflow-io-gcs-filesystem ------------------------------ 1.38 MiB/2.36 MiB
# h5py                         ------------------------------ 1.38 MiB/3.19 MiB
# tensorboard-data-server      ------------------------------ 1.41 MiB/4.60 MiB
# tensorboard                  ------------------------------ 1.38 MiB/5.24 MiB
# grpcio                       ------------------------------ 1.39 MiB/11.47 MiB
# numpy                        ------------------------------ 1.31 MiB/19.68 MiB
# libclang                     ------------------------------ 1.45 MiB/25.27 MiB
# ⠹ Preparing packages... (15/23)------------------------- 1.43 MiB/247.52 MiB
# tensorflow-io-gcs-filesystem ------------------------------ 1.38 MiB/2.36 MiB
# h5py                         ------------------------------ 1.38 MiB/3.19 MiB
# tensorboard-data-server      ------------------------------ 1.41 MiB/4.60 MiB
# tensorboard                  ------------------------------ 1.38 MiB/5.24 MiB
# grpcio                       ------------------------------ 1.39 MiB/11.47 MiB
# numpy                        ------------------------------ 1.31 MiB/19.68 MiB
# libclang                     ------------------------------ 1.47 MiB/25.27 MiB
# ⠸ Preparing packages... (15/23)------------------------- 1.43 MiB/247.52 MiB
# tensorflow-io-gcs-filesystem ------------------------------ 1.38 MiB/2.36 MiB
# h5py                         ------------------------------ 1.38 MiB/3.19 MiB
# tensorboard-data-server      ------------------------------ 1.41 MiB/4.60 MiB
# tensorboard                  ------------------------------ 1.38 MiB/5.24 MiB
# grpcio                       ------------------------------ 1.39 MiB/11.47 MiB
# numpy                        ------------------------------ 1.31 MiB/19.68 MiB
# libclang                     ------------------------------ 1.47 MiB/25.27 MiB
# tensorflow                   ------------------------------ 1.43 MiB/247.52 MiB
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/Desktop/tech/DSAI/.venv/lib/python3.9/site-packages/IPython/utils/_process_posix.py:153, in ProcessHandler.system(self, cmd)
#     150 while True:
#     151     # res is the index of the pattern that caused the match, so we
#     152     # know whether we've finished (if we matched EOF) or not
# --> 153     res_idx = child.expect_list(patterns, self.read_timeout)
#     154     print(child.before[out_size:].decode(enc, 'replace'), end='')
#
# File ~/Desktop/tech/DSAI/.venv/lib/python3.9/site-packages/pexpect/spawnbase.py:383, in SpawnBase.expect_list(self, pattern_list, timeout, searchwindowsize, async_, **kw)
#     382 else:
# --> 383     return exp.expect_loop(timeout)
#
# File ~/Desktop/tech/DSAI/.venv/lib/python3.9/site-packages/pexpect/expect.py:169, in Expecter.expect_loop(self, timeout)
#     168 # Still have time left, so read more data
# --> 169 incoming = spawn.read_nonblocking(spawn.maxread, timeout)
#     170 if self.spawn.delayafterread is not None:
#
# File ~/Desktop/tech/DSAI/.venv/lib/python3.9/site-packages/pexpect/pty_spawn.py:500, in spawn.read_nonblocking(self, size, timeout)
#     497 # Because of the select(0) check above, we know that no data
#     498 # is available right now. But if a non-zero timeout is given
#     499 # (possibly timeout=None), we call select() with a timeout.
# --> 500 if (timeout != 0) and select(timeout):
#     501     return super(spawn, self).read_nonblocking(size)
#
# File ~/Desktop/tech/DSAI/.venv/lib/python3.9/site-packages/pexpect/pty_spawn.py:450, in spawn.read_nonblocking.<locals>.select(timeout)
#     449 def select(timeout):
# --> 450     return select_ignore_interrupts([self.child_fd], [], [], timeout)[0]
#
# File ~/Desktop/tech/DSAI/.venv/lib/python3.9/site-packages/pexpect/utils.py:143, in select_ignore_interrupts(iwtd, owtd, ewtd, timeout)
#     142 try:
# --> 143     return select.select(iwtd, owtd, ewtd, timeout)
#     144 except InterruptedError:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 get_ipython().system('uv pip install tensorflow')
#
# File ~/Desktop/tech/DSAI/.venv/lib/python3.9/site-packages/ipykernel/zmqshell.py:710, in ZMQInteractiveShell.system_piped(self, cmd)
#     708         self.user_ns["_exit_code"] = system(cmd)
#     709 else:
# --> 710     self.user_ns["_exit_code"] = system(self.var_expand(cmd, depth=1))
#
# File ~/Desktop/tech/DSAI/.venv/lib/python3.9/site-packages/IPython/utils/_process_posix.py:164, in ProcessHandler.system(self, cmd)
#     159         out_size = len(child.before)
#     160 except KeyboardInterrupt:
#     161     # We need to send ^C to the process.  The ascii code for '^C' is 3
#     162     # (the character is known as ETX for 'End of Text', see
#     163     # curses.ascii.ETX).
# --> 164     child.sendline(chr(3))
#     165     # Read and print any more output the program might produce on its
#     166     # way out.
#     167     try:
#
# File ~/Desktop/tech/DSAI/.venv/lib/python3.9/site-packages/pexpect/pty_spawn.py:578, in spawn.sendline(self, s)
#     572 '''Wraps send(), sending string ``s`` to child process, with
#     573 ``os.linesep`` automatically appended. Returns number of bytes
#     574 written.  Only a limited number of bytes may be sent for each
#     575 line in the default terminal mode, see docstring of :meth:`send`.
#     576 '''
#     577 s = self._coerce_send_string(s)
# --> 578 return self.send(s + self.linesep)
#
# File ~/Desktop/tech/DSAI/.venv/lib/python3.9/site-packages/pexpect/pty_spawn.py:569, in spawn.send(self, s)
#     566 self._log(s, 'send')
#     568 b = self._encoder.encode(s, final=False)
# --> 569 return os.write(self.child_fd, b)
#
# OSError: [Errno 5] Input/output error

# %%
import tensorflow as tf
a = tf.constant(19)
print(a)

# %%
b = tf.constant([1 ,2, 3, 4])
print(b)

# %%
c = tf.constant([[1 ,2 ] , [ 3 , 4 ]])
print(c)

# %%
d = tf.constant([[[1,2],[3,4] ]])
